# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
from shapely.geometry import Point

# %%
# First to read data, you need change the file path to whather in your laptop
# use cse 163 environment so that all the package is install, more details in https://courses.cs.washington.edu/courses/cse163/software/ 
FILE_PATH = "C:/Users/718/Desktop/cse163/crime_in_la.csv"
la_crime_data = pd.read_csv(FILE_PATH)
la_crime_data.head()
coordinates = zip(la_crime_data['LON'], la_crime_data['LAT'])
la_crime_data['coordinates'] = [
    Point(-lon, lat) for lon, lat in coordinates
]
la_crime_data = gpd.GeoDataFrame(la_crime_data, geometry='coordinates')

# %%
la_crime_data.head()
# Out:
#        DR_NO    DATE OCC TIME OCC  AREA    AREA NAME  Rpt Dist No  Crm Cd  \
# 0   10304468  08/01/2020    22:30     3    Southwest          377     624
# 1  190101086  01/01/2020    03:30     1      Central          163     624
# 2  191501505  01/01/2020    17:30    15  N Hollywood         1543     745
# 3  191921269  01/01/2020    04:15    19      Mission         1998     740
# 4  200100501  01/01/2020    00:30     1      Central          163     121
#
#                                          Crm Cd Desc              Mocodes  \
# 0                           BATTERY - SIMPLE ASSAULT            0444 0913
# 1                           BATTERY - SIMPLE ASSAULT       0416 1822 1414
# 2           VANDALISM - MISDEAMEANOR ($399 OR UNDER)            0329 1402
# 3  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...                 0329
# 4                                     RAPE, FORCIBLE  0413 1822 1262 1415
#
#    Vict Age  ... Vict Descent                                   Premis Desc  \
# 0        36  ...            B                        SINGLE FAMILY DWELLING
# 1        25  ...            H                                      SIDEWALK
# 2        76  ...            W  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 3        31  ...            X                           BEAUTY SUPPLY STORE
# 4        25  ...            H               NIGHT CLUB (OPEN EVENINGS ONLY)
#
#   Weapon Used Cd                                     Weapon Desc Status  \
# 0          400.0  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     AO
# 1          500.0                     UNKNOWN WEAPON/OTHER WEAPON     IC
# 2          500.0                     UNKNOWN WEAPON/OTHER WEAPON     IC
# 3          500.0                     UNKNOWN WEAPON/OTHER WEAPON     IC
# 4          500.0                     UNKNOWN WEAPON/OTHER WEAPON     IC
#
#    Status Desc                                  LOCATION      LAT       LON  \
# 0  Adult Other   1100 W  39TH                         PL  34.0141 -118.2978
# 1  Invest Cont    700 S  HILL                         ST  34.0459 -118.2545
# 2  Invest Cont   5400    CORTEEN                      PL  34.1685 -118.4019
# 3  Invest Cont  14400    TITUS                        ST  34.2198 -118.4468
# 4  Invest Cont                           700 S  BROADWAY  34.0452 -118.2534
#
#                   coordinates
# 0  POINT (118.29780 34.01410)
# 1  POINT (118.25450 34.04590)
# 2  POINT (118.40190 34.16850)
# 3  POINT (118.44680 34.21980)
# 4  POINT (118.25340 34.04520)
#
# [5 rows x 21 columns]

# %%
la_map = gpd.read_file("C:/Users/718/Desktop/cse163/LAPD_map/LAPD_Divisions.shp")
# The area name in la_map is a little different with crime data. But we want those to match
# inorder to make some analysis, so we make change to let same area have same name.
# There is a test code to check if they match
la_map["APREC"] = la_map["APREC"].str.lower()
la_map["APREC"] = la_map["APREC"].replace(["north hollywood", "west los angeles"], ["n hollywood", "west la"])
la_crime_data["AREA NAME"] = la_crime_data["AREA NAME"].str.lower()

# %%
la_map.plot()
# Out:
# <AxesSubplot:>
